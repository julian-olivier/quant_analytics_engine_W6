# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

from src.data_loader import LocalCSVLoader
import src.math_functions as metrics

loader = LocalCSVLoader(data_directory="./data")
pltr = loader.load_clean_data('PLTR')
# Out:
#              close    volume     open      high       low
# date
# 2025-06-11  136.39  97366020  133.920  140.0000  132.9900
# 2025-06-12  135.19  56248180  136.400  137.0999  134.6300
# 2025-06-13  137.40  93519040  133.815  139.9900  133.3500
# 2025-06-16  141.41  80779770  140.030  144.8600  139.8115
# 2025-06-17  138.20  70479100  141.485  141.6900  136.0800
# ...            ...       ...      ...       ...       ...
# 2026-06-04  141.70  40834010  145.460  146.3700  140.2720
# 2026-06-05  135.53  38283520  140.325  141.9700  134.0250
# 2026-06-08  136.47  26978870  135.680  137.7600  135.2800
# 2026-06-09  132.07  38679990  134.870  136.9900  127.3500
# 2026-06-10  130.21  30612640  129.325  133.1850  128.8000
#
# [251 rows x 5 columns]
