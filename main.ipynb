# %% [markdown]
# ## imports & reading csv

# %%
import sys
import os
from src.data_loader import LocalCSVLoader
import src.math_functions as metrics
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath(os.path.join('..')))

loader = LocalCSVLoader(data_directory="./data")
pltr = loader.load_clean_data('PLTR')

# %% [markdown]
# ## testing

# %% [markdown]
# ### return math functions

# %%
metrics.calc_daily_returns(pltr)
metrics.calc_cumulative_returns(pltr)

print(metrics.calc_annualized_return(pltr))

display(pltr)
# Out:
# -0.045487593336100085
#              close    volume     open      high       low  daily_return  \
# date
# 2025-06-11  136.39  97366020  133.920  140.0000  132.9900           NaN
# 2025-06-12  135.19  56248180  136.400  137.0999  134.6300     -0.008798
# 2025-06-13  137.40  93519040  133.815  139.9900  133.3500      0.016347
# 2025-06-16  141.41  80779770  140.030  144.8600  139.8115      0.029185
# 2025-06-17  138.20  70479100  141.485  141.6900  136.0800     -0.022700
# ...            ...       ...      ...       ...       ...           ...
# 2026-06-04  141.70  40834010  145.460  146.3700  140.2720     -0.003516
# 2026-06-05  135.53  38283520  140.325  141.9700  134.0250     -0.043543
# 2026-06-08  136.47  26978870  135.680  137.7600  135.2800      0.006936
# 2026-06-09  132.07  38679990  134.870  136.9900  127.3500     -0.032242
# 2026-06-10  130.21  30612640  129.325  133.1850  128.8000     -0.014083
#
#             cumulative_return
# date
# 2025-06-11           0.000000
# 2025-06-12          -0.008798
# 2025-06-13           0.007405
# 2025-06-16           0.036806
# 2025-06-17           0.013271
# ...                       ...
# 2026-06-04           0.038932
# 2026-06-05          -0.006305
# 2026-06-08           0.000587
# 2026-06-09          -0.031674
# 2026-06-10          -0.045311
#
# [251 rows x 7 columns]
